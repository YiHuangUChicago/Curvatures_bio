# %%
import json
from Plotting import plot_performance

# %% [markdown]
# ## The records

# %%
records = {
    'AdaBoost': 
    {5: (0.594, 0.0195959179422654),
     6: (0.6014999999999999, 0.02127792283095318),
     7: (0.5675000000000001, 0.035337656968169255),
     8: (0.5610000000000002, 0.02321637353248782),
     9: (0.55, 0.021908902300206663),
     10: (0.5405, 0.02108909670896316),
     11: (0.5295, 0.02801338965566291),
     12: (0.507, 0.023473389188611023),
     13: (0.5105000000000001, 0.010712142642814284),
     14: (0.49049999999999994, 0.049241750578142535),
     15: (0.493, 0.012288205727444518)},
    'Random forest':
    {5: (0.475, 0.042485291572496),
     6: (0.44899999999999995, 0.0557584074378026),
     7: (0.4085, 0.0635039368858341),
     8: (0.38099999999999995, 0.06323764701504951),
     9: (0.364, 0.06077828559609097),
     10: (0.33799999999999997, 0.05491812087098394),
     11: (0.30799999999999994, 0.05221110992882645),
     12: (0.304, 0.047159304490206375),
     13: (0.24650000000000002, 0.0518917141748083),
     14: (0.23250000000000007, 0.06259992012774455),
     15: (0.21100000000000002, 0.06048966853934644)},
    'SVM':
    {5: (0.288, 0.08003749121505498),
     6: (0.27149999999999996, 0.06574762353119691),
     7: (0.2625, 0.06920079479312358),
     8: (0.16199999999999998, 0.05065570056765575),
     9: (0.17649999999999996, 0.07391041875135061),
     10: (0.135, 0.04994997497496871),
     11: (0.11549999999999998, 0.04188973621306297),
     12: (0.1155, 0.05286539510870983),
     13: (0.0915, 0.05111506627208849),
     14: (0.06900000000000002, 0.03590264614203247),
     15: (0.0695, 0.03680692869555947)},
    'label propagation': 
    {5: (0.11650000000000002, 0.039657912199206856),
     6: (0.09950000000000002, 0.04248234927590516),
     7: (0.07900000000000001, 0.028266588050205137),
     8: (0.06650000000000002, 0.017965244223221682),
     9: (0.04900000000000001, 0.018138357147217055),
     10: (0.03700000000000001, 0.013820274961085255),
     11: (0.0335, 0.015580436450882883),
     12: (0.030000000000000006, 0.011832159566199232),
     13: (0.027500000000000004, 0.011779218989389746),
     14: (0.024000000000000004, 0.011135528725660045),
     15: (0.026000000000000002, 0.011135528725660045)}
}

# %%
json.dump(records, open('SBM_3_records.txt', 'w'))
records = json.load(open('SBM_3_records.txt', 'r'))

# %%
x_values = range(5, 16)
offset = 0
plot_performance('Stochastic_Block_Model_3', records, x_values, offset=offset, string=True)

# %%
records = {
    'AdaBoost': 
    {5: (0.43600000000000005, 0.010677078252031272),
     6: (0.42749999999999994, 0.013369741957120911),
     7: (0.4125, 0.01089724735885168),
     8: (0.40449999999999997, 0.017741194999210178),
     9: (0.38550000000000006, 0.014309088021254197),
     10: (0.37950000000000006, 0.014991664350564963),
     11: (0.373, 0.016462077633154343),
     12: (0.36450000000000005, 0.012835497652993449),
     13: (0.3485, 0.011521718621802924),
     14: (0.34149999999999997, 0.018781639970992945),
     15: (0.3325, 0.01373863166403408)},
    'Random forest':
    {5: (0.40800000000000003, 0.05045790324617145),
     6: (0.37, 0.05709640969448079),
     7: (0.3665, 0.06612677218797239),
     8: (0.33099999999999996, 0.06276145313805281),
     9: (0.30850000000000005, 0.06589954476322277),
     10: (0.30500000000000005, 0.04295346318982905),
     11: (0.29100000000000004, 0.04938623289946298),
     12: (0.266, 0.05721887800367988),
     13: (0.2555, 0.07372075691418259),
     14: (0.27849999999999997, 0.053691246958885205),
     15: (0.24949999999999997, 0.04852576635149621)},
    'SVM':
    {5: (0.2745, 0.09708115162069308),
     6: (0.22650000000000006, 0.08833317610048899),
     7: (0.23399999999999999, 0.07572318007057019),
     8: (0.13999999999999996, 0.06760177512462229),
     9: (0.15150000000000002, 0.06405271266699014),
     10: (0.13599999999999998, 0.06681317235396027),
     11: (0.10300000000000001, 0.05225897052181568),
     12: (0.11999999999999997, 0.08485281374238568),
     13: (0.09649999999999999, 0.05712048669260443),
     14: (0.091, 0.05708765190476831),
     15: (0.07450000000000001, 0.03943031828428474)},
    'label propagation':
    {5: (0.0775, 0.04624662149822407),
     6: (0.0645, 0.04576843890717708),
     7: (0.053500000000000006, 0.03811495769379785),
     8: (0.04250000000000001, 0.021418449990603893),
     9: (0.035, 0.021563858652847823),
     10: (0.025, 0.016881943016134132),
     11: (0.03250000000000001, 0.016992645467966427),
     12: (0.021500000000000002, 0.011521718621802911),
     13: (0.022000000000000002, 0.015684387141358124),
     14: (0.0235, 0.015898113095584646),
     15: (0.015500000000000003, 0.012439855304624728)}
}

# %%
x_values = range(5, 16)
offset = 0
plot_performance('Stochastic_Block_Model_2', records, x_values, offset=offset)

# %% [markdown]
# ## Plot of the congress dataset

# %%
records ={
#     'AdaBoost': 
#     {5: (0.10428571428571427, 0.07493944832805216), 
#      10: (0.0784331797235023, 0.05297326727116375), 
#      15: (0.06635944700460829, 0.03484675497771348), 
#      20: (0.06751152073732719, 0.024346673639704247), 
#      25: (0.05612903225806451, 0.014752015114031397), 
#      30: (0.051566820276497685, 0.01439596227968677)},
    'SVM':
    {5: (0.10447004608294932, 0.023881507556977048), 
     10: (0.08972350230414747, 0.01789187940010202), 
     15: (0.07382488479262672, 0.017871393154506234), 
     20: (0.06953917050691244, 0.014851941891917117), 
     25: (0.05834101382488479, 0.01310280153305432), 
     30: (0.05534562211981567, 0.011395540940689324)},
    '1-dim\'l Gaussian':
    {5: (0.12776497695852534, 0.040381622344018264), 
     10: (0.10403225806451613, 0.011128698318639118), 
     15: (0.10368663594470047, 0.009829829035807163), 
     20: (0.09965437788018436, 0.008430629666578668), 
     25: (0.09988479262672811, 0.007296365914087101), 
     30: (0.09585253456221197, 0.007227828175741071)},
    '2-dim\'l Gaussian':
    {5: (0.12946635730858466, 0.029491010385959443), 
     10: (0.10881670533642691, 0.009922693633569882), 
     15: (0.10475638051044085, 0.010200244238807084), 
     20: (0.10058004640371229, 0.008342188579279257), 
     25: (0.09767981438515082, 0.007966721444728257), 
     30: (0.09535962877030162, 0.008034009138366953)}
}

# %%
json.dump(records, open('congress_records.txt', 'w'))
records = json.load(open('congress_records.txt', 'r'))

# %%
x_values = [5, 10, 15, 20, 25, 30]
offset = .5
plot_performance('UCI_Congress', records, x_values, offset=offset, string=True)

# %% [markdown]
# ## Plot of the mushroom dataset

# %%
records = {
#     'AdaBoost':
#     {10: (0.10268999999999999, 0.03771085917875646), 
#      20: (0.061579999999999996, 0.03177363057631281), 
#      30: (0.03839, 0.025122159540931187), 
#      40: (0.02717, 0.02041974779472068), 
#      50: (0.0123, 0.010340696301506976), 
#      60: (0.011889999999999998, 0.012380343290878488)},
    'SVM':
    {10: (0.11585000000000001, 0.041970138193720544), 
     20: (0.06286, 0.03131741368631835), 
     30: (0.03824, 0.02535532291255625), 
     40: (0.027200000000000002, 0.017819371481620782), 
     50: (0.01333, 0.010946967616650741), 
     60: (0.010819999999999998, 0.0102224067616193)},
    '1-dim\'l Gaussian':
    {10: (0.162225, 0.06510846239161235),
     20: (0.11735 ,0.041290162266573865),
     30: (0.086525 ,0.04961715303199086),
     40: (0.090025 ,0.030071778713604554),
     50: (0.055475 ,0.030471492825262105),
     60: (0.0454 ,0.028667751917442013)},
     '2-dim\'l Gaussian':
    {10: (0.1495, 0.037227677875473236),
     20: (0.090725, 0.0470652406240529),
     30: (0.08347500000000001, 0.043160883621631285),
     40: (0.075075, 0.03317539562687987),
     50: (0.07262500000000001, 0.03220515292620111),
     60: (0.0513, 0.025997788367474645)}
}

# %%
json.dump(records, open('Mushroom_records.txt', 'w'))
records = json.load(open('Mushroom_records.txt', 'r'))

# %%
x_values = [10, 20, 30, 40, 50, 60]
offset = .5
plot_performance('UCI_Mushroom', records, x_values, offset=offset, string=True)
